# %%
# !pip install transformers torch scikit-learn
# Out:
# Requirement already satisfied: transformers in c:\users\admin\anaconda2\lib\site-packages (4.57.3)
# Requirement already satisfied: torch in c:\users\admin\anaconda2\lib\site-packages (2.9.1)
# Requirement already satisfied: scikit-learn in c:\users\admin\anaconda2\lib\site-packages (1.7.2)
# Requirement already satisfied: filelock in c:\users\admin\anaconda2\lib\site-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\admin\anaconda2\lib\site-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\anaconda2\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda2\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\admin\anaconda2\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\admin\anaconda2\lib\site-packages (from transformers) (2025.9.1)
# Requirement already satisfied: requests in c:\users\admin\anaconda2\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\admin\anaconda2\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\admin\anaconda2\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\admin\anaconda2\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\admin\anaconda2\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\admin\anaconda2\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin\anaconda2\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\admin\anaconda2\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda2\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda2\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\admin\anaconda2\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\anaconda2\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\anaconda2\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\anaconda2\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda2\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda2\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda2\lib\site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda2\lib\site-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda2\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda2\lib\site-packages (from requests->transformers) (2025.11.12)

# %% [markdown]
# ## Import Libraries

# %%
import torch
from torch import nn
from transformers import BertTokenizer, BertModel

# %% [markdown]
# ## Define BERT Classification Model

# %%
class BertClassifier(nn.Module):
    def __init__(self, num_classes):
        super(BertClassifier, self).__init__()
        self.bert = BertModel.from_pretrained('bert-base-uncased')
        self.dropout = nn.Dropout(0.3)
        self.fc = nn.Linear(self.bert.config.hidden_size, num_classes)

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.pooler_output
        x = self.dropout(pooled_output)
        return self.fc(x)

# %% [markdown]
# ## Tokenize Input Text

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

text = "I really love using BERT models!"

encoded = tokenizer(
    text,
    padding='max_length',
    truncation=True,
    max_length=32,
    return_tensors='pt'
)

input_ids = encoded['input_ids']
attention_mask = encoded['attention_mask']

# %% [markdown]
# ## Run Inference

# %%
model = BertClassifier(num_classes=2)
model.eval()

with torch.no_grad():
    outputs = model(input_ids, attention_mask)
    prediction = torch.argmax(outputs, dim=1)

print('Predicted class:', prediction.item())
# Out:
# Predicted class: 0

# %% [markdown]
# ## ✅ Completed
# You have successfully run BERT text classification in Jupyter Notebook.
